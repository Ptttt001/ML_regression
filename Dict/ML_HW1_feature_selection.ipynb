# %% [markdown]
# <a href="https://colab.research.google.com/github/Ptttt001/ML_regression/blob/main/Dict/ML_HW1_feature_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown --id '1BjXalPZxq9mybPKNjF3h5L3NcF7XKTS-' --output covid_train.csv
# !gdown --id '1B55t74Jg2E5FCsKCsUEkPKIuqaY7UIi1' --output covid_test.csv
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1BjXalPZxq9mybPKNjF3h5L3NcF7XKTS-
# To: /content/covid_train.csv
# 100% 2.16M/2.16M [00:00<00:00, 158MB/s]
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1B55t74Jg2E5FCsKCsUEkPKIuqaY7UIi1
# To: /content/covid_test.csv
# 100% 638k/638k [00:00<00:00, 117MB/s]

# %%
import pandas as pd
X= pd.read_csv('covid_train.csv')

# %%
from sklearn.feature_selection import f_regression
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# UsageError: Line magic function `%configInlineBackend.figure_format='retina'` not found.

# %%
df = pd.DataFrame(X, columns = X.columns)
featuresCorr = df.corr()
plt.figure(figsize=(12,10))
sns.heatmap(featuresCorr, cmap=plt.cm.Reds,center=0, vmax=1, vmin=-1)
plt.show()

# %%
featuresCorr.to_csv("result.csv")

# %%
featuresCorr
# Out:
#                           id        AL        AZ        CA        CO  \
# id                  1.000000 -0.291841 -0.274256 -0.256672 -0.239087
# AL                 -0.291841  1.000000 -0.030127 -0.030127 -0.030127
# AZ                 -0.274256 -0.030127  1.000000 -0.030127 -0.030127
# CA                 -0.256672 -0.030127 -0.030127  1.000000 -0.030127
# CO                 -0.239087 -0.030127 -0.030127 -0.030127  1.000000
# ...                      ...       ...       ...       ...       ...
# nohh_cmnty_cli.2    0.316720 -0.107278 -0.043784 -0.152418  0.012463
# wearing_mask_7d.2  -0.028782 -0.091901 -0.039214  0.227271 -0.022366
# public_transit.2   -0.104725 -0.126555  0.004117  0.143146  0.086536
# worried_finances.2  0.080594  0.107087 -0.123259  0.032511 -0.131476
# tested_positive.2   0.437914 -0.108692 -0.049036 -0.189205 -0.033593
#
#                           CT        FL        GA        IL        IN  ...  \
# ...
